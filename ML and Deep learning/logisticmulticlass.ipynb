# %%
from sklearn.datasets import load_digits
# %matplotlib inline
import matplotlib.pyplot as plt
digits = load_digits()

# %%
plt.gray()
for i in range(5):
    plt.matshow(digits.images[i])

# %%
digits.data[0]
dir(digits)
digits.target[0:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(digits.data,digits.target,train_size=0.8)

# %%
model.fit(X_train,y_train)
X_test
# Out:
# c:\program files\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\program files\python37\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# array([[ 0.,  0.,  0., ..., 11.,  1.,  0.],
#        [ 0.,  0.,  2., ..., 10.,  1.,  0.],
#        [ 0.,  4., 15., ..., 12.,  3.,  0.],
#        ...,
#        [ 0.,  2., 12., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 11., 15.,  2.],
#        [ 0.,  0.,  5., ...,  0.,  0.,  0.]])

# %%
model.predict(digits.data[0:5])
# Out:
# array([0, 1, 2, 3, 4])

# %%
y_predicted= model.predict(X_test)
y_predicted
# Out:
# array([6, 6, 2, 7, 1, 2, 6, 6, 4, 8, 6, 1, 2, 4, 1, 7, 8, 4, 3, 6, 6, 0,
#        5, 4, 3, 1, 5, 8, 6, 2, 3, 6, 3, 7, 5, 4, 4, 6, 9, 3, 4, 3, 9, 0,
#        6, 5, 1, 5, 7, 2, 6, 6, 5, 8, 4, 5, 5, 6, 3, 7, 5, 5, 7, 6, 5, 1,
#        0, 0, 3, 5, 1, 5, 2, 5, 1, 0, 9, 3, 5, 5, 2, 5, 6, 4, 0, 0, 0, 0,
#        8, 2, 0, 5, 5, 5, 4, 0, 3, 1, 8, 4, 1, 2, 3, 5, 9, 2, 8, 0, 8, 9,
#        6, 3, 7, 2, 5, 8, 7, 6, 9, 3, 1, 8, 1, 5, 3, 2, 3, 0, 0, 4, 8, 5,
#        7, 1, 7, 7, 2, 4, 8, 3, 4, 4, 5, 9, 0, 7, 2, 1, 4, 2, 0, 1, 7, 8,
#        1, 8, 9, 7, 9, 8, 0, 9, 4, 2, 1, 4, 5, 6, 0, 4, 9, 9, 3, 1, 5, 2,
#        2, 1, 6, 4, 5, 5, 4, 6, 4, 2, 2, 7, 5, 6, 9, 3, 8, 2, 2, 4, 8, 4,
#        7, 5, 4, 0, 9, 2, 9, 9, 2, 1, 7, 7, 1, 6, 8, 8, 5, 4, 8, 4, 8, 6,
#        3, 9, 6, 0, 6, 1, 6, 5, 6, 7, 7, 4, 4, 6, 0, 7, 1, 9, 4, 3, 1, 7,
#        8, 6, 1, 6, 1, 0, 3, 6, 1, 7, 5, 5, 5, 1, 5, 6, 0, 1, 0, 5, 0, 9,
#        0, 5, 2, 6, 8, 0, 4, 1, 8, 6, 4, 5, 0, 1, 7, 4, 5, 2, 6, 1, 0, 6,
#        3, 3, 8, 2, 0, 0, 1, 8, 9, 9, 3, 9, 1, 0, 6, 0, 9, 4, 2, 6, 6, 1,
#        3, 5, 0, 6, 7, 1, 2, 6, 7, 8, 1, 5, 3, 6, 2, 6, 0, 4, 0, 3, 0, 1,
#        8, 7, 4, 4, 8, 2, 6, 6, 4, 4, 5, 1, 8, 7, 5, 5, 0, 4, 0, 1, 5, 6,
#        8, 3, 5, 7, 5, 5, 8, 1])

# %%
model.score(X_test,y_test)
# Out:
# 0.9555555555555556

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test,y_predicted)

# %%
import seaborn as sb
plt.figure(figsize=(10,7))
sb.heatmap(cm,annot=True)
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
